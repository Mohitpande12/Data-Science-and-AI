# %% [markdown]
# # variable_name = value

# %%
age = 25 # int variable
print(age)
# Out:
# 25

# %%
# string variable

name ="Alice"
print(name)
# Out:
# Alice

# %%
# float variable 
price = 19.99
print(price)
# Out:
# 19.99

# %%
# Bool variable 
active =True
print(active)
# Out:
# True

# %%
# storing and print the value
x =10
print(x)
# Out:
# 10

# %%
a = 5
b = 3
result = a +b
print(result)
# Out:
# 8

# %%
# changing the value of var
score = 50
print(score)

score = 120
print(score)
# Out:
# 50
# 120

# %%
# concatenating strings 
first_name = "John"
last_name = "Doe"

full_name = first_name +" " +last_name
print(full_name)
# Out:
# John Doe

# %%
# use var as calculation
length = 10
width = 4

area = length * width
print(area)
# Out:
# 40

# %%
x = 10
print(x)


x= 20
print(x)
# Out:
# 10
# 20
