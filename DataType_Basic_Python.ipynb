# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # Variable = Identifier = Object
# # vari name = value(value = data type)
#
# # never start with digit but it can end with digit

# %%
v = 5
v
# Out:
# 5

# %%
5v = 6
5v
# Out:
#   Cell In[3], line 1
#     5v = 6
#     ^
# SyntaxError: invalid decimal literal

# %%
nit = 7
NIT
# it is case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 nit = 7
# ----> 2 NIT
#       3 # it is case sensitive
#
# NameError: name 'NIT' is not defined

# %%
nit
# Out:
# 7

# %%
nit$ = 50
nit$
# Out:
#   Cell In[6], line 1
#     nit$ = 50
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # no special character allowed except underscore(((( ___  ))))

# %%
x_train = 80
x_train
# Out:
# 80

# %%
Nit =70 
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 Nit =70
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
Nit
# Out:
# 70

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
for = 60
for
# Out:
#   Cell In[11], line 1
#     for = 60
#         ^
# SyntaxError: invalid syntax

# %%
false = 67
false
# Out:
# 67

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
nit@ = 1
nit@
# Out:
#   Cell In[14], line 1
#     nit@ = 1
#          ^
# SyntaxError: invalid syntax

# %%
nit@1 = 1
nit@1
# Out:
#   Cell In[15], line 1
#     nit@1 = 1
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a_1 = "nit"
a_1
# Out:
# 'nit'

# %% [raw]
# # value == data type
# data type
# int
# float
# bool
# complex
# string

# %% [markdown]
# # Integer Datatype

# %%
i = 56 
i
# Out:
# 56

# %%
id(i)    # address of memory location
# Out:
# 140724512664200

# %%
type(i)   # it shows which data type it is
# Out:
# int

# %%
print(3 + 2)
# Out:
# 5

# %%
print( 3 - 2)
# Out:
# 1

# %%
print( 3 * 2)
# Out:
# 6

# %%
print(3 / 2)
# Out:
# 1.5

# %%
print(3//2)
# Out:
# 1

# %%
print(3 % 2)
# Out:
# 1

# %%
print(3 ** 2)
# Out:
# 9

# %%
# checking data type

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
print(type(22.7))
# Out:
# <class 'float'>

# %%
print(type(2+5j))
# Out:
# <class 'complex'>

# %%
print(type("Mohit"))
# Out:
# <class 'str'>

# %%
print(type([1,2,3]))
# Out:
# <class 'list'>

# %%
print(type({"name":"senapati"}))
# Out:
# <class 'dict'>

# %%
print(type({9.8,3.14,2.7}))
# Out:
# <class 'set'>

# %%
print(type((9.8,3.14,2.7)))
# Out:
# <class 'tuple'>

# %%
print(type(3==3))
# Out:
# <class 'bool'>

# %%
print(type(4  >= 3 ))
# Out:
# <class 'bool'>

# %%
i = 5 
i
# Out:
# 5

# %%
4 + 10
# Out:
# 14

# %%
_ + 5  # _ store the last value of output
# Out:
# 19

# %% [markdown]
# # Float

# %%
f = 105.10
f
# Out:
# 105.1

# %%
gold_price = 11000.56
gold_price
# Out:
# 11000.56

# %%
f2 = 2e0
f2
# Out:
# 2.0

# %%
type(f2)
# Out:
# float

# %%
f3 = 2e1
f3
# Out:
# 20.0

# %%
f4 = 2.5e2
f4
# Out:
# 250.0

# %%
f5 = 3.4E3
f5
# Out:
# 3400.0

# %% [markdown]
# # Boolean

# %%
True
# Out:
# True

# %%
TRUE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 TRUE
#
# NameError: name 'TRUE' is not defined

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
False
# Out:
# False

# %%
None

# %%
True +True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
False -False
# Out:
# 0

# %%
True * False
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
print(False - True)
# Out:
# -1

# %%
10/5
# Out:
# 2.0

# %%
10//5
# Out:
# 2

# %%
False /True
# Out:
# 0.0

# %% [markdown]
# # complex

# %%
c = 10 +2j
c
# Out:
# (10+2j)

# %%
type(c)
# Out:
# complex

# %%
d = 20+30j

# %%
print(c)
print(d)
# Out:
# (10+2j)
# (20+30j)

# %%
c + d
# Out:
# (30+32j)

# %%
c.conjugate()
# Out:
# (10-2j)

# %%
c.real()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 c.real()
#
# TypeError: 'float' object is not callable

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 2.0

# %% [markdown]
# # String

# %%
nit = "Data"
nit
# Out:
# 'Data'

# %%
nit1 = 'Data-Sci'
nit1
# Out:
# 'Data-Sci'

# %%
'''Welcome to nit'''
# Out:
# 'Welcome to nit'

# %%
"welcome 
to nit
7 pm batch 
Senapati sir
Batch"
# Out:
#   Cell In[75], line 1
#     "welcome
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'welcome 
to nit
7 pm batch 
Senapati sir
Batch'
# Out:
#   Cell In[76], line 1
#     'welcome
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''welcome 
to nit
7 pm batch 
Senapati sir
Batch'''
# Out:
# 'welcome \nto nit\n7 pm batch \nSenapati sir\nBatch'
